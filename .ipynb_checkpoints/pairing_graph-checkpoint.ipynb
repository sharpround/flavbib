# %%
import networkx as nx
import pickle
import matplotlib.pyplot as plt

pairing_dict = pickle.load(open("pairing.pickle", "rb"))

# %%
G = nx.Graph()
G.add_nodes_from(pairing_dict.keys())

# %%
import re

out = open('pairings.txt', 'w')
for flavor in pairing_dict:
    for l in pairing_dict[flavor]:
        n1 = flavor
        n2 = re.split(':|, esp.|\u2014| \(|\(| and| /', l.lower())[0]
        G.add_edge(n1, n2)

# %%
cliques = list(nx.enumerate_all_cliques(G))

# %%
pairing_dict['brussels sprouts']
# Out:
# ['Botanical relatives: broccoli, cabbage, cauliflower, collard greens, kale, kohlrabi',
#  'almonds',
#  'apple cider',
#  'apples and apple juice or cider',
#  'artichokes, Jerusalem',
#  'BACON',
#  'basil',
#  'bay leaf',
#  'bread crumbs',
#  'BUTTER, unsalted',
#  'celery',
#  'celery root',
#  'CHEESE: blue, cheddar, goat, Parmesan, provolone, ricotta, Swiss',
#  'chestnuts',
#  'chives',
#  'coriander',
#  'cream',
#  'crème fraîche',
#  'dill',
#  'eggs, hard-boiled',
#  'fennel seeds',
#  'garlic',
#  'hazelnuts',
#  'juniper berries',
#  'lemon, juice',
#  'marjoram',
#  'mustard, Dijon',
#  'nutmeg',
#  'oil, mustard',
#  'olive oil',
#  'onions',
#  'pancetta',
#  'paprika',
#  'parsley, flat-leaf',
#  'pepper: black, white',
#  'potatoes, esp. mashed',
#  'salt: kosher, sea',
#  'sauces, béchamel',
#  'shallots',
#  'stock, chicken',
#  'sugar',
#  'thyme, fresh',
#  'turnips',
#  'vermouth',
#  'vinaigrette',
#  'VINEGAR: cider, white wine',
#  'water chestnuts',
#  'wine, dry white']

# %%
import pickle

pickle.dump(cliques, open("cliques.pickel", "wb"))

# %%
for c in cliques:
    if len(c)>2:
        print(c)
# Out:
# ['', 'squid', 'rice, arborio or carnaroli']
# ['', 'squid', 'arugula']
# ['', 'squid', 'zucchini']
# ['', 'squid', 'walnuts']
# ['', 'squid', 'basil']
# ['', 'squid', 'shrimp']
# ['', 'squid', 'monkfish']
# ['', 'squid', 'chard']
# ['', 'squid', 'beans, white']
# ['', 'seafood—in general', 'wine']
# ['', 'wild rice', 'squash, winter']
# ['', 'pistachios', 'salmon']
# ['', 'pistachios', 'rose']
# ['', 'pistachios', 'arugula']
# ['', 'pistachios', 'nectarines']
# ['', 'pistachios', 'oranges, mandarin']
# ['', 'pistachios', 'prunes']
# ['', 'pistachios', 'snapper']
# ['', 'pistachios', 'basil']
# ['', 'pistachios', 'shrimp']
# ['', 'pistachios', 'plums, dried']
# ['', 'pistachios', 'poultry']
# ['', 'pistachios', 'cheese, goat—fresh']
# ['', 'pistachios', 'fruit, dried']
# ['', 'spinach', 'peas—in general']
# ['', 'spinach', 'salmon']
# ['', 'spinach', 'chickpeas']
# ['', 'spinach', 'pecans']
# ['', 'spinach', 'greek cuisine']
# ['', 'spinach', 'beans, fava']
# ['', 'spinach', 'venison']
# ['', 'spinach', 'smoked salmon']
# ['', 'spinach', 'pomelos']
# ['', 'spinach', 'squash, butternut']
# ['', 'spinach', 'rabbit']
# ['', 'spinach', 'snapper']
# ['', 'spinach', 'walnuts']
# ['', 'spinach', 'basil']
# ['', 'spinach', 'shrimp']
# ['', 'spinach', 'monkfish']
# ['', 'spinach', 'chard']
# ['', 'spinach', 'mushrooms—in general']
# ['', 'chile peppers, chipotle', 'tex-mex cuisine']
# ['', 'peas—in general', 'snap peas']
# ['', 'peas—in general', 'arugula']
# ['', 'peas—in general', 'basil']
# ['', 'peas—in general', 'shrimp']
# ['', 'peas—in general', 'poultry']
# ['', 'frisée', 'tangerines']
# ['', 'frisée', 'walnuts']
# ['', 'frisée', 'basil']
# ['', 'rice, arborio or carnaroli', 'arugula']
# ['', 'rice, arborio or carnaroli', 'shellfish']
# ['', 'rice, arborio or carnaroli', 'wine']
# ['', 'rice, arborio or carnaroli', 'basil']
# ['', 'rice, arborio or carnaroli', 'shrimp']
# ['', 'mediterranean cuisines', 'herbs']
# ['', 'mediterranean cuisines', 'basil']
# ['', 'pumpkin', 'anise']
# ['', 'pumpkin', 'pecans']
# ['', 'pumpkin', 'squash, winter']
# ['', 'pumpkin', 'venison']
# ['', 'pumpkin', 'argentinian cuisine']
# ['', 'pumpkin', 'walnuts']
# ['', 'pumpkin', 'shrimp']
# ['', 'pumpkin', 'brazilian cuisine']
# ['', 'anise', 'chinese cuisine']
# ['', 'anise', 'greek cuisine']
# ['', 'anise', 'shellfish']
# ['', 'anise', 'vegetables, root']
# ['', 'anise', 'star anise']
# ['', 'anise', 'prunes']
# ['', 'anise', 'walnuts']
# ['', 'anise', 'fish—in general']
# ['', 'anise', 'plums, dried']
# ['', 'anise', 'french cuisine, southern']
# ['', 'chinese cuisine', 'cabbage, napa']
# ['', 'chinese cuisine', 'peanuts and peanut butter']
# ['', 'chinese cuisine', 'oranges, mandarin']
# ['', 'chinese cuisine', 'star anise']
# ['', 'chinese cuisine', 'vegetables']
# ['', 'chinese cuisine', 'shrimp']
# ['', 'calamari', 'peppers, piquillo']
# ['', 'snap peas', 'salmon']
# ['', 'snap peas', 'basil']
# ['', 'snap peas', 'shrimp']
# ['', 'snap peas', 'sesame oil']
# ['', 'whiskey', 'pecans']
# ['', 'whiskey', 'walnuts']
# ['', 'whiskey', 'plums, dried']
# ['', 'bourbon', 'pecans']
# ['', 'bourbon', 'venison']
# ['', 'bourbon', 'fruit, tropical']
# ['', 'bourbon', 'squash, butternut']
# ['', 'bourbon', 'walnuts']
# ['', 'bourbon', 'beans, white']
# ['', 'salmon', 'peppers, piquillo']
# ['', 'salmon', 'arugula']
# ['', 'salmon', 'pepper, green']
# ['', 'salmon', 'wine']
# ['', 'salmon', 'smoked salmon']
# ['', 'salmon', 'ramps']
# ['', 'salmon', 'zucchini']
# ['', 'salmon', 'basil']
# ['', 'salmon', 'monkfish']
# ['', 'salmon', 'bass']
# ['', 'hazelnut oil', 'shrimp']
# ['', 'chickpeas', 'peppers, piquillo']
# ['', 'chickpeas', 'squash, winter']
# ['', 'chickpeas', 'squash, butternut']
# ['', 'chickpeas', 'walnuts']
# ['', 'chickpeas', 'basil']
# ['', 'chickpeas', 'shrimp']
# ['', 'chickpeas', 'chard']
# ['', 'chickpeas', 'african cuisine (north)']
# ['', 'peppers, piquillo', 'shrimp']
# ['', 'beef—steak: filet mignon', 'wine']
# ['', 'cabbage, napa', 'shellfish']
# ['', 'peanuts and peanut butter', 'african cuisine']
# ['', 'peanuts and peanut butter', 'basil']
# ['', 'peanuts and peanut butter', 'shrimp']
# ['', 'arugula', 'shellfish']
# ['', 'arugula', 'rabbit']
# ['', 'arugula', 'greens—in general']
# ['', 'arugula', 'basil']
# ['', 'arugula', 'shrimp']
# ['', 'arugula', 'monkfish']
# ['', 'arugula', 'lettuce, bibb']
# ['', 'arugula', 'beans, white']
# ['', 'lettuces—mesclun greens', 'basil']
# ['', 'african cuisine', 'yams']
# ['', 'swiss chard', 'monkfish']
# ['', 'nectarines', 'pecans']
# ['', 'nectarines', 'wine']
# ['', 'nectarines', 'venison']
# ['', 'nectarines', 'walnuts']
# ['', 'nectarines', 'basil']
# ['', 'pepper, green', 'venison']
# ['', 'pepper, green', 'vegetables']
# ['', 'pepper, green', 'shrimp']
# ['', 'pecans', 'wine']
# ['', 'pecans', 'squash, winter']
# ['', 'pecans', 'melon/muskmelons—in general']
# ['', 'pecans', 'squash, summer']
# ['', 'pecans', 'zucchini']
# ['', 'pecans', 'prunes']
# ['', 'pecans', 'squash, butternut']
# ['', 'pecans', 'walnuts']
# ['', 'pecans', 'plums, dried']
# ['', 'pecans', 'cheese, goat—fresh']
# ['', 'greek cuisine', 'shellfish']
# ['', 'greek cuisine', 'zucchini']
# ['', 'greek cuisine', 'citrus—in general']
# ['', 'greek cuisine', 'basil']
# ['', 'shellfish', 'oranges, mandarin']
# ['', 'shellfish', 'beans, fava']
# ['', 'shellfish', 'greens—in general']
# ['', 'shellfish', 'citrus—in general']
# ['', 'shellfish', 'basil']
# ['', 'shellfish', 'french cuisine, southern']
# ['', 'shellfish', 'kaffir limes and kaffir lime leaf']
# ['', 'wine', 'venison']
# ['', 'wine', 'squash, butternut']
# ['', 'wine', 'rabbit']
# ['', 'wine', 'walnuts']
# ['', 'wine', 'shrimp']
# ['', 'wine', 'monkfish']
# ['', 'wine', 'fish—in general']
# ['', 'wine', 'plums, dried']
# ['', 'wine', 'mushrooms—in general']
# ['', 'wine', 'french cuisine, southern']
# ['', 'oranges, mandarin', 'shrimp']
# ['', 'oranges, mandarin', 'sesame oil']
# ['', 'greens, salad', 'cheese, goat—fresh']
# ['', 'star anise', 'venison']
# ['', 'star anise', 'rabbit']
# ['', 'star anise', 'snapper']
# ['', 'star anise', 'shrimp']
# ['', 'star anise', 'monkfish']
# ['', 'star anise', 'bass']
# ['', 'star anise', 'plums, dried']
# ['', 'star anise', 'cheese, goat—fresh']
# ['', 'star anise', 'kaffir limes and kaffir lime leaf']
# ['', 'thyme, lemon', 'shrimp']
# ['', 'beans, fava', 'steak']
# ['', 'beans, fava', 'herbs']
# ['', 'beans, fava', 'rabbit']
# ['', 'beans, fava', 'walnuts']
# ['', 'beans, fava', 'asian cuisine']
# ['', 'beans, fava', 'poultry']
# ['', 'squash, winter', 'walnuts']
# ['', 'squash, winter', 'truffles, white']
# ['', 'squash, winter', 'beans, white']
# ['', 'melon/muskmelons—in general', 'basil']
# ['', 'onions, sweet', 'herbs']
# ['', 'onions, sweet', 'basil']
# ['', 'onions, sweet', 'chard']
# ['', 'cheese, blue', 'walnuts']
# ['', 'herbs', 'hotness']
# ['', 'herbs', 'iranian cuisine']
# ['', 'herbs', 'mushrooms—in general']
# ['', 'herbs', 'cheese, goat—fresh']
# ['', 'squash, summer', 'walnuts']
# ['', 'squash, summer', 'basil']
# ['', 'zucchini', 'walnuts']
# ['', 'zucchini', 'basil']
# ['', 'zucchini', 'shrimp']
# ['', 'zucchini', 'crayfish']
# ['', 'pomelos', 'shrimp']
# ['', 'prunes', 'rabbit']
# ['', 'prunes', 'walnuts']
# ['', 'prunes', 'iranian cuisine']
# ['', 'squash, butternut', 'yams']
# ['', 'squash, butternut', 'walnuts']
# ['', 'squash, butternut', 'basil']
# ['', 'squash, butternut', 'shrimp']
# ['', 'rabbit', 'basil']
# ['', 'rabbit', 'plums, dried']
# ['', 'chicory', 'greens—in general']
# ['', 'chicory', 'shrimp']
# ['', 'greens—in general', 'basil']
# ['', 'greens—in general', 'legumes']
# ['', 'snapper', 'basil']
# ['', 'snapper', 'shrimp']
# ['', 'walnut oil', 'walnuts']
# ['', 'kohlrabi', 'basil']
# ['', 'walnuts', 'monkfish']
# ['', 'walnuts', 'plums, dried']
# ['', 'walnuts', 'mushrooms—in general']
# ['', 'walnuts', 'lettuces—bitter greens and chicories']
# ['', 'walnuts', 'cheese, goat—fresh']
# ['', 'walnuts', 'fruit, dried']
# ['', 'basil', 'vegetables']
# ['', 'basil', 'shrimp']
# ['', 'basil', 'monkfish']
# ['', 'basil', 'chard']
# ['', 'basil', 'lettuce, bibb']
# ['', 'basil', 'fish—in general']
# ['', 'basil', 'iranian cuisine']
# ['', 'basil', 'asian cuisine']
# ['', 'basil', 'mushrooms—in general']
# ['', 'basil', 'french cuisine, southern']
# ['', 'basil', 'poultry']
# ['', 'basil', 'lettuces—bitter greens and chicories']
# ['', 'basil', 'cheese, goat—fresh']
# ['', 'basil', 'sausages']
# ['', 'basil', 'squash, spaghetti']
# ['', 'basil', 'beans, white']
# ['', 'basil', 'crayfish']
# ['', 'vegetables', 'hotness']
# ['', 'vegetables', 'french cuisine, southern']
# ['', 'vegetables', 'north african cuisine']
# ['', 'vegetables', 'kaffir limes and kaffir lime leaf']
# ['', 'shrimp', 'monkfish']
# ['', 'shrimp', 'sausages']
# ['', 'brazilian cuisine', 'sausages']
# ['', 'monkfish', 'chard']
# ['', 'monkfish', 'beans, white']
# ['', 'monkfish', 'striped bass']
# ['', 'beans, cannellini', 'sausages']
# ['', 'sesame oil', 'mushrooms—in general']
# ['', 'mushrooms—in general', 'poultry']
# ['', 'poultry', 'kaffir limes and kaffir lime leaf']
# ['', 'sausages', 'beans, white']
# ['pears', 'mint—in general', 'strawberries']
# ['pears', 'mint—in general', 'sage']
# ['pears', 'mint—in general', 'endive']
# ['pears', 'mint—in general', 'blackberries']
# ['pears', 'mint—in general', 'bourbon']
# ['pears', 'mint—in general', 'orange']
# ['pears', 'mint—in general', 'beets']
# ['pears', 'mint—in general', 'crème fraîche']
# ['pears', 'mint—in general', 'radishes']
# ['pears', 'mint—in general', 'chocolate']
# ['pears', 'mint—in general', 'dill']
# ['pears', 'mint—in general', 'sugar']
# ['pears', 'mint—in general', 'cardamom']
# ['pears', 'mint—in general', 'cinnamon']
# ['pears', 'mint—in general', 'pepper']
# ['pears', 'mint—in general', 'ginger']
# ['pears', 'mint—in general', 'grapes']
# ['pears', 'mint—in general', 'cream']
# ['pears', 'mint—in general', 'cheese']
# ['pears', 'mint—in general', 'raspberries']
# ['pears', 'mint—in general', 'vinegar']
# ['pears', 'mint—in general', 'vanilla']
# ['pears', 'mint—in general', 'cloves']
# ['pears', 'mint—in general', 'salads']
# ['pears', 'mint—in general', 'pork']
# ['pears', 'mint—in general', 'duck']
# ['pears', 'mint—in general', 'meats']
# ['pears', 'mint—in general', 'thyme']
# ['pears', 'mint—in general', 'basil']
# ['pears', 'mint—in general', 'mediterranean cuisine']
# ['pears', 'mint—in general', 'rice']
# ['pears', 'mint—in general', 'chicken']
# ['pears', 'mint—in general', 'rosemary']
# ['pears', 'mint—in general', 'poultry']
# ['pears', 'mint—in general', 'champagne']
# ['pears', 'mint—in general', 'lemon']
# ['pears', 'mint—in general', 'honey']
# ['pears', 'mint—in general', 'apples']
# ['pears', 'cheese, jack', 'pecans']
# ['pears', 'cheese, jack', 'prunes']
# ['pears', 'cheese, jack', 'almonds']
# ['pears', 'cheese, jack', 'walnuts']
# ['pears', 'cheese, jack', 'figs']
# ['pears', 'apricots', 'pistachios']
# ['pears', 'apricots', 'custards']
# ['pears', 'apricots', 'blackberries']
# ['pears', 'apricots', 'horseradish']
# ['pears', 'apricots', 'cardamom']
# ['pears', 'apricots', 'pecans']
# ['pears', 'apricots', 'cinnamon']
# ['pears', 'apricots', 'blueberries']
# ['pears', 'apricots', 'ginger']
# ['pears', 'apricots', 'lemons']
# ['pears', 'apricots', 'melon/muskmelons—in general']
# ['pears', 'apricots', 'cheese, gouda']
# ['pears', 'apricots', 'pork—in general']
# ['pears', 'apricots', 'raspberries']
# ['pears', 'apricots', 'foie gras']
# ['pears', 'apricots', 'sweetness']
# ['pears', 'apricots', 'vanilla']
# ['pears', 'apricots', 'oatmeal / oats']
# ['pears', 'apricots', 'maple syrup']
# ['pears', 'apricots', 'chocolate / cocoa—in general']
# ['pears', 'apricots', 'almonds']
# ['pears', 'apricots', 'duck']
# ['pears', 'apricots', 'cranberries']
# ['pears', 'apricots', 'macadamia nuts']
# ['pears', 'apricots', 'walnuts']
# ['pears', 'apricots', 'caramel']
# ['pears', 'apricots', 'basil']
# ['pears', 'apricots', 'oranges—in general']
# ['pears', 'apricots', 'anise hyssop']
# ['pears', 'apricots', 'pine nuts']
# ['pears', 'apricots', 'verjus']
# ['pears', 'apricots', 'mascarpone']
# ['pears', 'apricots', 'rosemary']
# ['pears', 'apricots', 'cheese, goat—fresh']
# ['pears', 'apricots', 'honey']
# ['pears', 'apricots', 'hazelnuts']
# ['pears', 'apricots', 'dates']
# ['pears', 'apricots', 'apples']
# ['pears', 'cream cheese', 'celery']
# ['pears', 'cream cheese', 'salt']
# ['pears', 'cream cheese', 'strawberries']
# ['pears', 'cream cheese', 'sage']
# ['pears', 'cream cheese', 'rum']
# ['pears', 'cream cheese', 'endive']
# ['pears', 'cream cheese', 'raisins']
# ['pears', 'cream cheese', 'blackberries']
# ['pears', 'cream cheese', 'crème fraîche']
# ['pears', 'cream cheese', 'lychees']
# ['pears', 'cream cheese', 'radishes']
# ['pears', 'cream cheese', 'passion fruit']
# ['pears', 'cream cheese', 'horseradish']
# ['pears', 'cream cheese', 'rhubarb']
# ['pears', 'cream cheese', 'dill']
# ['pears', 'cream cheese', 'sugar']
# ['pears', 'cream cheese', 'cinnamon']
# ['pears', 'cream cheese', 'blueberries']
# ['pears', 'cream cheese', 'ginger']
# ['pears', 'cream cheese', 'figs, fresh']
# ['pears', 'cream cheese', 'cream']
# ['pears', 'cream cheese', 'lemons']
# ['pears', 'cream cheese', 'sour cream']
# ['pears', 'cream cheese', 'cheese']
# ['pears', 'cream cheese', 'raspberries']
# ['pears', 'cream cheese', 'cherries']
# ['pears', 'cream cheese', 'cheese, blue']
# ['pears', 'cream cheese', 'nutmeg']
# ['pears', 'cream cheese', 'vanilla']
# ['pears', 'cream cheese', 'cloves']
# ['pears', 'cream cheese', 'maple syrup']
# ['pears', 'cream cheese', 'chocolate / cocoa—in general']
# ['pears', 'cream cheese', 'almonds']
# ['pears', 'cream cheese', 'cranberries']
# ['pears', 'cream cheese', 'walnuts']
# ['pears', 'cream cheese', 'caramel']
# ['pears', 'cream cheese', 'rutabagas']
# ['pears', 'cream cheese', 'mascarpone']
# ['pears', 'cream cheese', 'rosemary']
# ['pears', 'cream cheese', 'lemon']
# ['pears', 'cream cheese', 'honey']
# ['pears', 'cream cheese', 'hazelnuts']
# ['pears', 'cream cheese', 'dates']
# ['pears', 'celery', 'salt']
# ['pears', 'celery', 'endive']
# ['pears', 'celery', 'mustard']
# ['pears', 'celery', 'chestnuts']
# ['pears', 'celery', 'beets']
# ['pears', 'celery', 'cheese—in general']
# ['pears', 'celery', 'olive oil']
# ['pears', 'celery', 'radishes']
# ['pears', 'celery', 'peanuts']
# ['pears', 'celery', 'horseradish']
# ['pears', 'celery', 'dill']
# ['pears', 'celery', 'ginger']
# ['pears', 'celery', 'cream']
# ['pears', 'celery', 'liver, calf’s']
# ['pears', 'celery', 'cheese']
# ['pears', 'celery', 'pork—in general']
# ['pears', 'celery', 'vinegar']
# ['pears', 'celery', 'venison']
# ['pears', 'celery', 'cheese, blue']
# ['pears', 'celery', 'squash, butternut']
# ['pears', 'celery', 'salads']
# ['pears', 'celery', 'duck']
# ['pears', 'celery', 'thyme']
# ['pears', 'celery', 'truffles, black']
# ['pears', 'celery', 'bay leaf']
# ['pears', 'celery', 'basil']
# ['pears', 'celery', 'bacon']
# ['pears', 'celery', 'rutabagas']
# ['pears', 'celery', 'rice']
# ['pears', 'celery', 'chicken']
# ['pears', 'celery', 'rosemary']
# ['pears', 'celery', 'apples']
# ['pears', 'quail', 'pistachios']
# ['pears', 'quail', 'salt']
# ['pears', 'quail', 'vinegar, banyuls']
# ['pears', 'quail', 'sage']
# ['pears', 'quail', 'orange']
# ['pears', 'quail', 'chestnuts']
# ['pears', 'quail', 'olive oil']
# ['pears', 'quail', 'italian cuisine']
# ['pears', 'quail', 'ham']
# ['pears', 'quail', 'arugula']
# ['pears', 'quail', 'cardamom']
# ['pears', 'quail', 'cinnamon']
# ['pears', 'quail', 'parsley, flat-leaf']
# ['pears', 'quail', 'prosciutto']
# ['pears', 'quail', 'grapes']
# ['pears', 'quail', 'wine']
# ['pears', 'quail', 'figs, fresh']
# ['pears', 'quail', 'cream']
# ['pears', 'quail', 'vinegar']
# ['pears', 'quail', 'foie gras']
# ['pears', 'quail', 'cloves']
# ['pears', 'quail', 'maple syrup']
# ['pears', 'quail', 'almonds']
# ['pears', 'quail', 'brandy']
# ['pears', 'quail', 'thyme']
# ['pears', 'quail', 'tamarind']
# ['pears', 'quail', 'bay leaf']
# ['pears', 'quail', 'walnuts']
# ['pears', 'quail', 'bacon']
# ['pears', 'quail', 'figs']
# ['pears', 'quail', 'truffles, white']
# ['pears', 'quail', 'pine nuts']
# ['pears', 'quail', 'verjus']
# ['pears', 'quail', 'coriander']
# ['pears', 'quail', 'rosemary']
# ['pears', 'quail', 'butter, unsalted']
# ['pears', 'quail', 'honey']
# ['pears', 'quail', 'hazelnuts']
# ['pears', 'quail', 'fennel']
# ['pears', 'quail', 'mint']
# ['pears', 'quail', 'apples']
# ['pears', 'pistachios', 'strawberries']
# ['pears', 'pistachios', 'cheese, brie']
# ['pears', 'pistachios', 'endive']
# ['pears', 'pistachios', 'raisins']
# ['pears', 'pistachios', 'cheese, gorgonzola']
# ['pears', 'pistachios', 'orange']
# ['pears', 'pistachios', 'beets']
# ['pears', 'pistachios', 'italian cuisine']
# ['pears', 'pistachios', 'figs, dried']
# ['pears', 'pistachios', 'chocolate']
# ['pears', 'pistachios', 'arugula']
# ['pears', 'pistachios', 'sugar']
# ['pears', 'pistachios', 'cardamom']
# ['pears', 'pistachios', 'ginger']
# ['pears', 'pistachios', 'grapes']
# ['pears', 'pistachios', 'figs, fresh']
# ['pears', 'pistachios', 'cream']
# ['pears', 'pistachios', 'lemons']
# ['pears', 'pistachios', 'cheese']
# ['pears', 'pistachios', 'raspberries']
# ['pears', 'pistachios', 'cherries']
# ['pears', 'pistachios', 'foie gras']
# ['pears', 'pistachios', 'vanilla']
# ['pears', 'pistachios', 'prunes']
# ['pears', 'pistachios', 'autumn']
# ['pears', 'pistachios', 'duck']
# ['pears', 'pistachios', 'cranberries']
# ['pears', 'pistachios', 'basil']
# ['pears', 'pistachios', 'oranges—in general']
# ['pears', 'pistachios', 'figs']
# ['pears', 'pistachios', 'plums, dried']
# ['pears', 'pistachios', 'rice']
# ['pears', 'pistachios', 'mascarpone']
# ['pears', 'pistachios', 'chicken']
# ['pears', 'pistachios', 'rosemary']
# ['pears', 'pistachios', 'poultry']
# ['pears', 'pistachios', 'cheese, goat—fresh']
# ['pears', 'pistachios', 'lemon']
# ['pears', 'pistachios', 'honey']
# ['pears', 'pistachios', 'dates']
# ['pears', 'pistachios', 'apples']
# ['pears', 'french cuisine', 'cheese, brie']
# ['pears', 'french cuisine', 'sage']
# ['pears', 'french cuisine', 'endive']
# ['pears', 'french cuisine', 'mustard']
# ['pears', 'french cuisine', 'mace']
# ['pears', 'french cuisine', 'beets']
# ['pears', 'french cuisine', 'crème fraîche']
# ['pears', 'french cuisine', 'ham']
# ['pears', 'french cuisine', 'figs, fresh']
# ['pears', 'french cuisine', 'liver, calf’s']
# ['pears', 'french cuisine', 'watercress']
# ['pears', 'french cuisine', 'pork—in general']
# ['pears', 'french cuisine', 'foie gras']
# ['pears', 'french cuisine', 'nutmeg']
# ['pears', 'french cuisine', 'thyme']
# ['pears', 'french cuisine', 'truffles, black']
# ['pears', 'french cuisine', 'bay leaf']
# ['pears', 'french cuisine', 'basil']
# ['pears', 'french cuisine', 'bacon']
# ['pears', 'french cuisine', 'pine nuts']
# ['pears', 'french cuisine', 'plums, dried']
# ['pears', 'french cuisine', 'rosemary']
# ['pears', 'french cuisine', 'calvados']
# ['pears', 'french cuisine', 'apples']
# ['pears', 'salt', 'vinegar, banyuls']
# ['pears', 'salt', 'cheese, roquefort']
# ['pears', 'salt', 'endive']
# ['pears', 'salt', 'parsnips']
# ['pears', 'salt', 'blackberries']
# ['pears', 'salt', 'mustard']
# ['pears', 'salt', 'persimmons']
# ['pears', 'salt', 'beets']
# ['pears', 'salt', 'olive oil']
# ['pears', 'salt', 'peanuts and peanut butter']
# ['pears', 'salt', 'radishes']
# ['pears', 'salt', 'arugula']
# ['pears', 'salt', 'horseradish']
# ['pears', 'salt', 'rhubarb']
# ['pears', 'salt', 'squab']
# ['pears', 'salt', 'pecans']
# ['pears', 'salt', 'grapes']
# ['pears', 'salt', 'watercress']
# ['pears', 'salt', 'pork—in general']
# ['pears', 'salt', 'oatmeal / oats']
# ['pears', 'salt', 'squash, butternut']
# ['pears', 'salt', 'chocolate / cocoa—in general']
# ['pears', 'salt', 'almonds']
# ['pears', 'salt', 'duck']
# ['pears', 'salt', 'cranberries']
# ['pears', 'salt', 'walnuts']
# ['pears', 'salt', 'basil']
# ['pears', 'salt', 'oranges—in general']
# ['pears', 'salt', 'bacon']
# ['pears', 'salt', 'truffles, white']
# ['pears', 'salt', 'radicchio']
# ['pears', 'salt', 'rutabagas']
# ['pears', 'salt', 'lettuces—in general']
# ['pears', 'salt', 'chicken']
# ['pears', 'salt', 'fennel']
# ['pears', 'cheese, camembert', 'strawberries']
# ['pears', 'cheese, camembert', 'olive oil']
# ['pears', 'cheese, camembert', 'arugula']
# ['pears', 'cheese, camembert', 'pecans']
# ['pears', 'cheese, camembert', 'grapes']
# ['pears', 'cheese, camembert', 'vinegar']
# ['pears', 'cheese, camembert', 'nuts']
# ['pears', 'cheese, camembert', 'salads']
# ['pears', 'strawberries', 'cheese, brie']
# ['pears', 'strawberries', 'custards']
# ['pears', 'strawberries', 'rum']
# ['pears', 'strawberries', 'anise']
# ['pears', 'strawberries', 'blackberries']
# ['pears', 'strawberries', 'orange']
# ['pears', 'strawberries', 'crème fraîche']
# ['pears', 'strawberries', 'lychees']
# ['pears', 'strawberries', 'peanuts and peanut butter']
# ['pears', 'strawberries', 'chocolate']
# ['pears', 'strawberries', 'peanuts']
# ['pears', 'strawberries', 'passion fruit']
# ['pears', 'strawberries', 'cardamom']
# ['pears', 'strawberries', 'pecans']
# ['pears', 'strawberries', 'cinnamon']
# ['pears', 'strawberries', 'blueberries']
# ['pears', 'strawberries', 'ginger']
# ['pears', 'strawberries', 'grapes']
# ['pears', 'strawberries', 'kirsch']
# ['pears', 'strawberries', 'wine']
# ['pears', 'strawberries', 'melon/muskmelons—in general']
# ['pears', 'strawberries', 'sour cream']
# ['pears', 'strawberries', 'cheese']
# ['pears', 'strawberries', 'raspberries']
# ['pears', 'strawberries', 'foie gras']
# ['pears', 'strawberries', 'sweetness']
# ['pears', 'strawberries', 'nutmeg']
# ['pears', 'strawberries', 'vanilla']
# ['pears', 'strawberries', 'oatmeal / oats']
# ['pears', 'strawberries', 'cloves']
# ['pears', 'strawberries', 'maple syrup']
# ['pears', 'strawberries', 'chocolate / cocoa—in general']
# ['pears', 'strawberries', 'almonds']
# ['pears', 'strawberries', 'brandy']
# ['pears', 'strawberries', 'bay leaf']
# ['pears', 'strawberries', 'walnuts']
# ['pears', 'strawberries', 'caramel']
# ['pears', 'strawberries', 'oranges—in general']
# ['pears', 'strawberries', 'pine nuts']
# ['pears', 'strawberries', 'verjus']
# ['pears', 'strawberries', 'mascarpone']
# ['pears', 'strawberries', 'port']
# ['pears', 'strawberries', 'coriander']
# ['pears', 'strawberries', 'rosemary']
# ['pears', 'strawberries', 'cheese, goat—fresh']
# ['pears', 'strawberries', 'champagne']
# ['pears', 'strawberries', 'lemon']
# ['pears', 'strawberries', 'honey']
# ['pears', 'strawberries', 'hazelnuts']
# ['pears', 'strawberries', 'mint']
# ['pears', 'cheese, brie', 'nuts']
# ['pears', 'cheese, brie', 'cherries']
# ['pears', 'cheese, brie', 'almonds']
# ['pears', 'cheese, brie', 'figs']
# ['pears', 'cheese, brie', 'chicken']
# ['pears', 'cheese, brie', 'fennel']
# ['pears', 'cheese, brie', 'dates']
# ['pears', 'cheese, brie', 'apples']
# ['pears', 'vinegar, banyuls', 'beets']
# ['pears', 'vinegar, banyuls', 'olive oil']
# ['pears', 'vinegar, banyuls', 'cream']
# ['pears', 'vinegar, banyuls', 'cheese']
# ['pears', 'vinegar, banyuls', 'nuts']
# ['pears', 'vinegar, banyuls', 'foie gras']
# ['pears', 'vinegar, banyuls', 'salads']
# ['pears', 'vinegar, banyuls', 'duck']
# ['pears', 'vinegar, banyuls', 'meats']
# ['pears', 'vinegar, banyuls', 'walnuts']
# ['pears', 'vinegar, banyuls', 'honey']
# ['pears', 'oil, walnut', 'cheese, roquefort']
# ['pears', 'oil, walnut', 'persimmons']
# ['pears', 'oil, walnut', 'beets']
# ['pears', 'oil, walnut', 'vinegar']
# ['pears', 'oil, walnut', 'salads']
# ['pears', 'oil, walnut', 'meats']
# ['pears', 'oil, walnut', 'walnuts']
# ['pears', 'oil, walnut', 'figs']
# ['pears', 'oil, walnut', 'apples']
# ['pears', 'sage', 'parsnips']
# ['pears', 'sage', 'orange']
# ['pears', 'sage', 'chestnuts']
# ['pears', 'sage', 'olive oil']
# ['pears', 'sage', 'italian cuisine']
# ['pears', 'sage', 'ham']
# ['pears', 'sage', 'squab']
# ['pears', 'sage', 'parsley, flat-leaf']
# ['pears', 'sage', 'blueberries']
# ['pears', 'sage', 'prosciutto']
# ['pears', 'sage', 'wine']
# ['pears', 'sage', 'cream']
# ['pears', 'sage', 'lemons']
# ['pears', 'sage', 'squash, winter']
# ['pears', 'sage', 'liver, calf’s']
# ['pears', 'sage', 'cheese']
# ['pears', 'sage', 'pork—in general']
# ['pears', 'sage', 'game']
# ['pears', 'sage', 'venison']
# ['pears', 'sage', 'cherries']
# ['pears', 'sage', 'sweet potatoes']
# ['pears', 'sage', 'squash, butternut']
# ['pears', 'sage', 'salads']
# ['pears', 'sage', 'greens—in general']
# ['pears', 'sage', 'duck']
# ['pears', 'sage', 'thyme']
# ['pears', 'sage', 'bay leaf']
# ['pears', 'sage', 'walnuts']
# ['pears', 'sage', 'mediterranean cuisine']
# ['pears', 'sage', 'rutabagas']
# ['pears', 'sage', 'rice']
# ['pears', 'sage', 'chicken']
# ['pears', 'sage', 'rosemary']
# ['pears', 'sage', 'poultry']
# ['pears', 'sage', 'winter']
# ['pears', 'sage', 'cheese, goat—fresh']
# ['pears', 'sage', 'lemon']
# ['pears', 'sage', 'honey']
# ['pears', 'sage', 'fennel']
# ['pears', 'sage', 'mint']
# ['pears', 'sage', 'apples']
# ['pears', 'cheese, roquefort', 'pepper']
# ['pears', 'cheese, roquefort', 'wine']
# ['pears', 'cheese, roquefort', 'cream']
# ['pears', 'cheese, roquefort', 'walnuts']
# ['pears', 'cheese, roquefort', 'figs']
# ['pears', 'cheese, roquefort', 'butter, unsalted']
# ['pears', 'cheese, roquefort', 'honey']
# ['pears', 'custards', 'raisins']
# ['pears', 'custards', 'persimmons']
# ['pears', 'custards', 'liqueurs']
# ['pears', 'custards', 'orange']
# ['pears', 'custards', 'chocolate']
# ['pears', 'custards', 'passion fruit']
# ['pears', 'custards', 'rhubarb']
# ['pears', 'custards', 'cardamom']
# ['pears', 'custards', 'cinnamon']
# ['pears', 'custards', 'ginger']
# ['pears', 'custards', 'raspberries']
# ['pears', 'custards', 'cherries']
# ['pears', 'custards', 'sweet potatoes']
# ['pears', 'custards', 'nutmeg']
# ['pears', 'custards', 'vanilla']
# ['pears', 'custards', 'maple syrup']
# ['pears', 'custards', 'prunes']
# ['pears', 'custards', 'coffee and espresso']
# ['pears', 'custards', 'almonds']
# ['pears', 'custards', 'thyme']
# ['pears', 'custards', 'bay leaf']
# ['pears', 'custards', 'walnuts']
# ['pears', 'custards', 'caramel']
# ['pears', 'custards', 'basil']
# ['pears', 'custards', 'anise hyssop']
# ['pears', 'custards', 'lemon']
# ['pears', 'custards', 'hazelnuts']
# ['pears', 'custards', 'apples']
# ['pears', 'rum', 'raisins']
# ['pears', 'rum', 'persimmons']
# ['pears', 'rum', 'orange']
# ['pears', 'rum', 'chestnuts']
# ['pears', 'rum', 'lychees']
# ['pears', 'rum', 'chocolate']
# ['pears', 'rum', 'passion fruit']
# ['pears', 'rum', 'sugar']
# ['pears', 'rum', 'butterscotch']
# ['pears', 'rum', 'pecans']
# ['pears', 'rum', 'cinnamon']
# ['pears', 'rum', 'blueberries']
# ['pears', 'rum', 'ginger']
# ['pears', 'rum', 'grapes']
# ['pears', 'rum', 'figs, fresh']
# ['pears', 'rum', 'cream']
# ['pears', 'rum', 'lemons']
# ['pears', 'rum', 'melon/muskmelons—in general']
# ['pears', 'rum', 'nuts']
# ['pears', 'rum', 'sweet potatoes']
# ['pears', 'rum', 'nutmeg']
# ['pears', 'rum', 'vanilla']
# ['pears', 'rum', 'maple syrup']
# ['pears', 'rum', 'coffee and espresso']
# ['pears', 'rum', 'chocolate / cocoa—in general']
# ['pears', 'rum', 'almonds']
# ['pears', 'rum', 'macadamia nuts']
# ['pears', 'rum', 'walnuts']
# ['pears', 'rum', 'caramel']
# ['pears', 'rum', 'oranges—in general']
# ['pears', 'rum', 'pine nuts']
# ['pears', 'rum', 'plums, dried']
# ['pears', 'rum', 'mascarpone']
# ['pears', 'rum', 'cheese, goat—fresh']
# ['pears', 'rum', 'calvados']
# ['pears', 'rum', 'lemon']
# ['pears', 'rum', 'honey']
# ['pears', 'rum', 'hazelnuts']
# ['pears', 'rum', 'dates']
# ['pears', 'rum', 'mint']
# ['pears', 'rum', 'apples']
# ['pears', 'quinces', 'autumn']
# ['pears', 'endive', 'mustard']
# ['pears', 'endive', 'persimmons']
# ['pears', 'endive', 'orange']
# ['pears', 'endive', 'beets']
# ['pears', 'endive', 'crème fraîche']
# ['pears', 'endive', 'olive oil']
# ['pears', 'endive', 'peanuts']
# ['pears', 'endive', 'arugula']
# ['pears', 'endive', 'horseradish']
# ['pears', 'endive', 'sugar']
# ['pears', 'endive', 'pecans']
# ['pears', 'endive', 'cinnamon']
# ['pears', 'endive', 'parsley, flat-leaf']
# ['pears', 'endive', 'pepper']
# ['pears', 'endive', 'ginger']
# ['pears', 'endive', 'grapes']
# ['pears', 'endive', 'cream']
# ['pears', 'endive', 'sour cream']
# ['pears', 'endive', 'cheese']
# ['pears', 'endive', 'watercress']
# ['pears', 'endive', 'cheese, fontina']
# ['pears', 'endive', 'vinegar']
# ['pears', 'endive', 'game']
# ['pears', 'endive', 'nuts']
# ['pears', 'endive', 'foie gras']
# ['pears', 'endive', 'salads']
# ['pears', 'endive', 'almonds']
# ['pears', 'endive', 'thyme']
# ['pears', 'endive', 'bay leaf']
# ['pears', 'endive', 'walnuts']
# ['pears', 'endive', 'basil']
# ['pears', 'endive', 'bacon']
# ['pears', 'endive', 'radicchio']
# ['pears', 'endive', 'chicken']
# ['pears', 'endive', 'coriander']
# ['pears', 'endive', 'rosemary']
# ['pears', 'endive', 'butter, unsalted']
# ['pears', 'endive', 'honey']
# ['pears', 'endive', 'fennel']
# ['pears', 'endive', 'apples']
# ['pears', 'anise', 'chinese cuisine']
# ['pears', 'anise', 'raisins']
# ['pears', 'anise', 'parsnips']
# ['pears', 'anise', 'orange']
# ['pears', 'anise', 'chestnuts']
# ['pears', 'anise', 'beets']
# ['pears', 'anise', 'rhubarb']
# ['pears', 'anise', 'sugar']
# ['pears', 'anise', 'cardamom']
# ['pears', 'anise', 'cinnamon']
# ['pears', 'anise', 'pepper']
# ['pears', 'anise', 'ginger']
# ['pears', 'anise', 'figs, fresh']
# ['pears', 'anise', 'cream']
# ['pears', 'anise', 'star anise']
# ['pears', 'anise', 'lemons']
# ['pears', 'anise', 'cheese']
# ['pears', 'anise', 'pork—in general']
# ['pears', 'anise', 'nuts']
# ['pears', 'anise', 'sweet potatoes']
# ['pears', 'anise', 'nutmeg']
# ['pears', 'anise', 'vanilla']
# ['pears', 'anise', 'cloves']
# ['pears', 'anise', 'maple syrup']
# ['pears', 'anise', 'prunes']
# ['pears', 'anise', 'coffee and espresso']
# ['pears', 'anise', 'pork']
# ['pears', 'anise', 'almonds']
# ['pears', 'anise', 'duck']
# ['pears', 'anise', 'walnuts']
# ['pears', 'anise', 'figs']
# ['pears', 'anise', 'mediterranean cuisine']
# ['pears', 'anise', 'plums, dried']
# ['pears', 'anise', 'chicken']
# ['pears', 'anise', 'coriander']
# ['pears', 'anise', 'allspice']
# ['pears', 'anise', 'lemon']
# ['pears', 'anise', 'hazelnuts']
# ['pears', 'anise', 'fennel']
# ['pears', 'anise', 'dates']
# ['pears', 'anise', 'apples']
# ['pears', 'chinese cuisine', 'peanuts and peanut butter']
# ['pears', 'chinese cuisine', 'peanuts']
# ['pears', 'chinese cuisine', 'sugar']
# ['pears', 'chinese cuisine', 'cinnamon']
# ['pears', 'chinese cuisine', 'ginger']
# ['pears', 'chinese cuisine', 'star anise']
# ['pears', 'chinese cuisine', 'watercress']
# ['pears', 'chinese cuisine', 'pork—in general']
# ['pears', 'chinese cuisine', 'nutmeg']
# ['pears', 'chinese cuisine', 'cloves']
# ['pears', 'chinese cuisine', 'pork']
# ['pears', 'chinese cuisine', 'duck']
# ['pears', 'chinese cuisine', 'tamarind']
# ['pears', 'chinese cuisine', 'anise, star']
# ['pears', 'chinese cuisine', 'rice']
# ['pears', 'chinese cuisine', 'chicken']
# ['pears', 'chinese cuisine', 'honey']
# ['pears', 'raisins', 'whiskey']
# ['pears', 'raisins', 'persimmons']
# ['pears', 'raisins', 'orange']
# ['pears', 'raisins', 'chestnuts']
# ['pears', 'raisins', 'crème fraîche']
# ['pears', 'raisins', 'italian cuisine']
# ['pears', 'raisins', 'peanuts and peanut butter']
# ['pears', 'raisins', 'figs, dried']
# ['pears', 'raisins', 'chocolate']
# ['pears', 'raisins', 'peanuts']
# ['pears', 'raisins', 'sugar']
# ['pears', 'raisins', 'pecans']
# ['pears', 'raisins', 'cinnamon']
# ['pears', 'raisins', 'ginger']
# ['pears', 'raisins', 'wine']
# ['pears', 'raisins', 'lemons']
# ['pears', 'raisins', 'sour cream']
# ['pears', 'raisins', 'cheese']
# ['pears', 'raisins', 'nuts']
# ['pears', 'raisins', 'venison']
# ['pears', 'raisins', 'sweet potatoes']
# ['pears', 'raisins', 'foie gras']
# ['pears', 'raisins', 'sweetness']
# ['pears', 'raisins', 'nutmeg']
# ['pears', 'raisins', 'vanilla']
# ['pears', 'raisins', 'oatmeal / oats']
# ['pears', 'raisins', 'cloves']
# ['pears', 'raisins', 'maple syrup']
# ['pears', 'raisins', 'prunes']
# ['pears', 'raisins', 'coffee and espresso']
# ['pears', 'raisins', 'chocolate / cocoa—in general']
# ['pears', 'raisins', 'salads']
# ['pears', 'raisins', 'almonds']
# ['pears', 'raisins', 'brandy']
# ['pears', 'raisins', 'cranberries']
# ['pears', 'raisins', 'walnuts']
# ['pears', 'raisins', 'caramel']
# ['pears', 'raisins', 'oranges—in general']
# ['pears', 'raisins', 'pine nuts']
# ['pears', 'raisins', 'rutabagas']
# ['pears', 'raisins', 'lettuces—in general']
# ['pears', 'raisins', 'plums, dried']
# ['pears', 'raisins', 'rice']
# ['pears', 'raisins', 'mascarpone']
# ['pears', 'raisins', 'chicken']
# ['pears', 'raisins', 'allspice']
# ['pears', 'raisins', 'butter, unsalted']
# ['pears', 'raisins', 'lemon']
# ['pears', 'raisins', 'honey']
# ['pears', 'raisins', 'hazelnuts']
# ['pears', 'raisins', 'dates']
# ['pears', 'raisins', 'apples']
# ['pears', 'cheese, gorgonzola', 'olive oil']
# ['pears', 'cheese, gorgonzola', 'italian cuisine']
# ['pears', 'cheese, gorgonzola', 'sugar']
# ['pears', 'cheese, gorgonzola', 'prosciutto']
# ['pears', 'cheese, gorgonzola', 'grapes']
# ['pears', 'cheese, gorgonzola', 'cream']
# ['pears', 'cheese, gorgonzola', 'nuts']
# ['pears', 'cheese, gorgonzola', 'cherries']
# ['pears', 'cheese, gorgonzola', 'salads']
# ['pears', 'cheese, gorgonzola', 'brandy']
# ['pears', 'cheese, gorgonzola', 'thyme']
# ['pears', 'cheese, gorgonzola', 'walnuts']
# ['pears', 'cheese, gorgonzola', 'figs']
# ['pears', 'cheese, gorgonzola', 'honey']
# ['pears', 'cheese, gorgonzola', 'mint']
# ['pears', 'cheese, gorgonzola', 'apples']
# ['pears', 'parsnips', 'mustard']
# ['pears', 'parsnips', 'mace']
# ['pears', 'parsnips', 'orange']
# ['pears', 'parsnips', 'olive oil']
# ['pears', 'parsnips', 'dill']
# ['pears', 'parsnips', 'cardamom']
# ['pears', 'parsnips', 'cinnamon']
# ['pears', 'parsnips', 'pepper']
# ['pears', 'parsnips', 'ginger']
# ['pears', 'parsnips', 'cream']
# ['pears', 'parsnips', 'cheese']
# ['pears', 'parsnips', 'butter, brown']
# ['pears', 'parsnips', 'game']
# ['pears', 'parsnips', 'venison']
# ['pears', 'parsnips', 'sweetness']
# ['pears', 'parsnips', 'nutmeg']
# ['pears', 'parsnips', 'maple syrup']
# ['pears', 'parsnips', 'squash, butternut']
# ['pears', 'parsnips', 'duck']
# ['pears', 'parsnips', 'meats']
# ['pears', 'parsnips', 'thyme']
# ['pears', 'parsnips', 'bay leaf']
# ['pears', 'parsnips', 'basil']
# ['pears', 'parsnips', 'bacon']
# ['pears', 'parsnips', 'anise hyssop']
# ['pears', 'parsnips', 'rutabagas']
# ['pears', 'parsnips', 'chicken']
# ['pears', 'parsnips', 'coriander']
# ['pears', 'parsnips', 'rosemary']
# ['pears', 'parsnips', 'allspice']
# ['pears', 'parsnips', 'honey']
# ['pears', 'parsnips', 'fennel']
# ['pears', 'parsnips', 'mint']
# ['pears', 'parsnips', 'apples']
# ['pears', 'blackberries', 'oats']
# ['pears', 'blackberries', 'crème fraîche']
# ['pears', 'blackberries', 'lychees']
# ['pears', 'blackberries', 'chocolate']
# ['pears', 'blackberries', 'sugar']
# ['pears', 'blackberries', 'pecans']
# ['pears', 'blackberries', 'cinnamon']
# ['pears', 'blackberries', 'blueberries']
# ['pears', 'blackberries', 'ginger']
# ['pears', 'blackberries', 'kirsch']
# ['pears', 'blackberries', 'wine']
# ['pears', 'blackberries', 'cream']
# ['pears', 'blackberries', 'lemons']
# ['pears', 'blackberries', 'melon/muskmelons—in general']
# ['pears', 'blackberries', 'sour cream']
# ['pears', 'blackberries', 'grand marnier']
# ['pears', 'blackberries', 'raspberries']
# ['pears', 'blackberries', 'vanilla']
# ['pears', 'blackberries', 'cloves']
# ['pears', 'blackberries', 'pork']
# ['pears', 'blackberries', 'almonds']
# ['pears', 'blackberries', 'brandy']
# ['pears', 'blackberries', 'caramel']
# ['pears', 'blackberries', 'oranges—in general']
# ['pears', 'blackberries', 'mascarpone']
# ['pears', 'blackberries', 'cheese, goat—fresh']
# ['pears', 'blackberries', 'champagne']
# ['pears', 'blackberries', 'butter, unsalted']
# ['pears', 'blackberries', 'honey']
# ['pears', 'blackberries', 'hazelnuts']
# ['pears', 'blackberries', 'mint']
# ['pears', 'blackberries', 'apples']
# ['pears', 'whiskey', 'chocolate']
# ['pears', 'whiskey', 'sugar']
# ['pears', 'whiskey', 'pecans']
# ['pears', 'whiskey', 'cinnamon']
# ['pears', 'whiskey', 'cream']
# ['pears', 'whiskey', 'sweet potatoes']
# ['pears', 'whiskey', 'vanilla']
# ['pears', 'whiskey', 'maple syrup']
# ['pears', 'whiskey', 'walnuts']
# ['pears', 'whiskey', 'figs']
# ['pears', 'whiskey', 'plums, dried']
# ['pears', 'whiskey', 'chicken']
# ['pears', 'whiskey', 'allspice']
# ['pears', 'whiskey', 'honey']
# ['pears', 'bourbon', 'persimmons']
# ['pears', 'bourbon', 'sugar']
# ['pears', 'bourbon', 'butterscotch']
# ['pears', 'bourbon', 'pecans']
# ['pears', 'bourbon', 'ginger']
# ['pears', 'bourbon', 'cream']
# ['pears', 'bourbon', 'venison']
# ['pears', 'bourbon', 'sweet potatoes']
# ['pears', 'bourbon', 'squash, butternut']
# ['pears', 'bourbon', 'coffee and espresso']
# ['pears', 'bourbon', 'chocolate / cocoa—in general']
# ['pears', 'bourbon', 'brandy']
# ['pears', 'bourbon', 'macadamia nuts']
# ['pears', 'bourbon', 'walnuts']
# ['pears', 'bourbon', 'caramel']
# ['pears', 'bourbon', 'honey']
# ['pears', 'bourbon', 'mint']
# ['pears', 'bourbon', 'apples']
# ['pears', 'mustard', 'beets']
# ['pears', 'mustard', 'olive oil']
# ['pears', 'mustard', 'italian cuisine']
# ['pears', 'mustard', 'ham']
# ['pears', 'mustard', 'horseradish']
# ['pears', 'mustard', 'dill']
# ['pears', 'mustard', 'squab']
# ['pears', 'mustard', 'pepper']
# ['pears', 'mustard', 'prosciutto']
# ['pears', 'mustard', 'cream']
# ['pears', 'mustard', 'squash, winter']
# ['pears', 'mustard', 'sour cream']
# ['pears', 'mustard', 'watercress']
# ['pears', 'mustard', 'vinegar']
# ['pears', 'mustard', 'venison']
# ['pears', 'mustard', 'sweet potatoes']
# ['pears', 'mustard', 'salads']
# ['pears', 'mustard', 'pork']
# ['pears', 'mustard', 'thyme']
# ['pears', 'mustard', 'tamarind']
# ['pears', 'mustard', 'bay leaf']
# ['pears', 'mustard', 'walnuts']
# ['pears', 'mustard', 'basil']
# ['pears', 'mustard', 'mediterranean cuisine']
# ['pears', 'mustard', 'rutabagas']
# ['pears', 'mustard', 'mascarpone']
# ['pears', 'mustard', 'chicken']
# ['pears', 'mustard', 'coriander']
# ['pears', 'mustard', 'poultry']
# ['pears', 'mustard', 'allspice']
# ['pears', 'mustard', 'honey']
# ['pears', 'mustard', 'oil, canola']
# ['pears', 'mustard', 'fennel']
# ['pears', 'mustard', 'mint']
# ['pears', 'mustard', 'apples']
# ['pears', 'mace', 'persimmons']
# ['pears', 'mace', 'chocolate']
# ['pears', 'mace', 'cardamom']
# ['pears', 'mace', 'cinnamon']
# ['pears', 'mace', 'pepper']
# ['pears', 'mace', 'blueberries']
# ['pears', 'mace', 'ginger']
# ['pears', 'mace', 'cream']
# ['pears', 'mace', 'cheese']
# ['pears', 'mace', 'pork—in general']
# ['pears', 'mace', 'sweet potatoes']
# ['pears', 'mace', 'nutmeg']
# ['pears', 'mace', 'cloves']
# ['pears', 'mace', 'meats']
# ['pears', 'mace', 'thyme']
# ['pears', 'mace', 'anise, star']
# ['pears', 'mace', 'rutabagas']
# ['pears', 'mace', 'chicken']
# ['pears', 'mace', 'coriander']
# ['pears', 'mace', 'allspice']
# ['pears', 'mace', 'astringency']
# ['pears', 'mace', 'hazelnuts']
# ['pears', 'oats', 'figs, dried']
# ['pears', 'oats', 'pecans']
# ['pears', 'oats', 'blueberries']
# ['pears', 'oats', 'ginger']
# ['pears', 'oats', 'lemons']
# ['pears', 'oats', 'maple syrup']
# ['pears', 'oats', 'coffee and espresso']
# ['pears', 'oats', 'chocolate / cocoa—in general']
# ['pears', 'oats', 'almonds']
# ['pears', 'oats', 'cranberries']
# ['pears', 'oats', 'oranges—in general']
# ['pears', 'oats', 'mascarpone']
# ['pears', 'oats', 'honey']
# ['pears', 'oats', 'hazelnuts']
# ['pears', 'oats', 'dates']
# ['pears', 'persimmons', 'liqueurs']
# ['pears', 'persimmons', 'orange']
# ['pears', 'persimmons', 'oil, hazelnut']
# ['pears', 'persimmons', 'olive oil']
# ['pears', 'persimmons', 'sugar']
# ['pears', 'persimmons', 'pecans']
# ['pears', 'persimmons', 'cinnamon']
# ['pears', 'persimmons', 'ginger']
# ['pears', 'persimmons', 'prosciutto']
# ['pears', 'persimmons', 'grapes']
# ['pears', 'persimmons', 'kirsch']
# ['pears', 'persimmons', 'cream']
# ['pears', 'persimmons', 'lemons']
# ['pears', 'persimmons', 'cheese']
# ['pears', 'persimmons', 'watercress']
# ['pears', 'persimmons', 'vinegar']
# ['pears', 'persimmons', 'sweet potatoes']
# ['pears', 'persimmons', 'sweetness']
# ['pears', 'persimmons', 'nutmeg']
# ['pears', 'persimmons', 'vanilla']
# ['pears', 'persimmons', 'oatmeal / oats']
# ['pears', 'persimmons', 'cloves']
# ['pears', 'persimmons', 'maple syrup']
# ['pears', 'persimmons', 'coffee and espresso']
# ['pears', 'persimmons', 'salads']
# ['pears', 'persimmons', 'pork']
# ['pears', 'persimmons', 'autumn']
# ['pears', 'persimmons', 'almonds']
# ['pears', 'persimmons', 'brandy']
# ['pears', 'persimmons', 'walnuts']
# ['pears', 'persimmons', 'caramel']
# ['pears', 'persimmons', 'oranges—in general']
# ['pears', 'persimmons', 'radicchio']
# ['pears', 'persimmons', 'poultry']
# ['pears', 'persimmons', 'astringency']
# ['pears', 'persimmons', 'lemon']
# ['pears', 'persimmons', 'honey']
# ['pears', 'persimmons', 'hazelnuts']
# ['pears', 'persimmons', 'apples']
# ['pears', 'liqueurs', 'blueberries']
# ['pears', 'liqueurs', 'figs, fresh']
# ['pears', 'liqueurs', 'lemons']
# ['pears', 'liqueurs', 'raspberries']
# ['pears', 'liqueurs', 'sweet potatoes']
# ['pears', 'liqueurs', 'chocolate / cocoa—in general']
# ['pears', 'liqueurs', 'anise, star']
# ['pears', 'liqueurs', 'plums, dried']
# ['pears', 'orange', 'chestnuts']
# ['pears', 'orange', 'figs, dried']
# ['pears', 'orange', 'radishes']
# ['pears', 'orange', 'cardamom']
# ['pears', 'orange', 'pecans']
# ['pears', 'orange', 'cinnamon']
# ['pears', 'orange', 'blueberries']
# ['pears', 'orange', 'ginger']
# ['pears', 'orange', 'figs, fresh']
# ['pears', 'orange', 'lemons']
# ['pears', 'orange', 'squash, winter']
# ['pears', 'orange', 'melon/muskmelons—in general']
# ['pears', 'orange', 'watercress']
# ['pears', 'orange', 'pork—in general']
# ['pears', 'orange', 'raspberries']
# ['pears', 'orange', 'venison']
# ['pears', 'orange', 'sweet potatoes']
# ['pears', 'orange', 'vanilla']
# ['pears', 'orange', 'oatmeal / oats']
# ['pears', 'orange', 'cloves']
# ['pears', 'orange', 'maple syrup']
# ['pears', 'orange', 'coffee and espresso']
# ['pears', 'orange', 'chocolate / cocoa—in general']
# ['pears', 'orange', 'almonds']
# ['pears', 'orange', 'duck']
# ['pears', 'orange', 'thyme']
# ['pears', 'orange', 'cranberries']
# ['pears', 'orange', 'tamarind']
# ['pears', 'orange', 'macadamia nuts']
# ['pears', 'orange', 'walnuts']
# ['pears', 'orange', 'basil']
# ['pears', 'orange', 'pine nuts']
# ['pears', 'orange', 'radicchio']
# ['pears', 'orange', 'lettuces—in general']
# ['pears', 'orange', 'mascarpone']
# ['pears', 'orange', 'coriander']
# ['pears', 'orange', 'rosemary']
# ['pears', 'orange', 'cheese, goat—fresh']
# ['pears', 'orange', 'honey']
# ['pears', 'orange', 'hazelnuts']
# ['pears', 'orange', 'vinegar, sherry']
# ['pears', 'orange', 'fennel']
# ['pears', 'orange', 'dates']
# ['pears', 'orange', 'shiso leaf']
# ['pears', 'orange', 'apples']
# ['pears', 'chestnuts', 'crème fraîche']
# ['pears', 'chestnuts', 'olive oil']
# ['pears', 'chestnuts', 'italian cuisine']
# ['pears', 'chestnuts', 'figs, dried']
# ['pears', 'chestnuts', 'chocolate']
# ['pears', 'chestnuts', 'ham']
# ['pears', 'chestnuts', 'sugar']
# ['pears', 'chestnuts', 'cardamom']
# ['pears', 'chestnuts', 'cinnamon']
# ['pears', 'chestnuts', 'pepper']
# ['pears', 'chestnuts', 'ginger']
# ['pears', 'chestnuts', 'prosciutto']
# ['pears', 'chestnuts', 'wine']
# ['pears', 'chestnuts', 'lemons']
# ['pears', 'chestnuts', 'raspberries']
# ['pears', 'chestnuts', 'game']
# ['pears', 'chestnuts', 'venison']
# ['pears', 'chestnuts', 'sweet potatoes']
# ['pears', 'chestnuts', 'sweetness']
# ['pears', 'chestnuts', 'nutmeg']
# ['pears', 'chestnuts', 'vanilla']
# ['pears', 'chestnuts', 'cloves']
# ['pears', 'chestnuts', 'maple syrup']
# ['pears', 'chestnuts', 'prunes']
# ['pears', 'chestnuts', 'squash, butternut']
# ['pears', 'chestnuts', 'pork']
# ['pears', 'chestnuts', 'autumn']
# ['pears', 'chestnuts', 'brandy']
# ['pears', 'chestnuts', 'duck']
# ['pears', 'chestnuts', 'meats']
# ['pears', 'chestnuts', 'thyme']
# ['pears', 'chestnuts', 'bay leaf']
# ['pears', 'chestnuts', 'walnuts']
# ['pears', 'chestnuts', 'caramel']
# ['pears', 'chestnuts', 'oranges—in general']
# ['pears', 'chestnuts', 'bacon']
# ['pears', 'chestnuts', 'figs']
# ['pears', 'chestnuts', 'anise, star']
# ['pears', 'chestnuts', 'mascarpone']
# ['pears', 'chestnuts', 'chicken']
# ['pears', 'chestnuts', 'poultry']
# ['pears', 'chestnuts', 'butter, unsalted']
# ['pears', 'chestnuts', 'honey']
# ['pears', 'chestnuts', 'hazelnuts']
# ['pears', 'chestnuts', 'fennel']
# ['pears', 'chestnuts', 'apples']
# ['pears', 'oil, hazelnut', 'squab']
# ['pears', 'oil, hazelnut', 'salads']
# ['pears', 'oil, hazelnut', 'figs']
# ['pears', 'oil, hazelnut', 'hazelnuts']
# ['pears', 'oil, hazelnut', 'apples']
# ['pears', 'beets', 'crème fraîche']
# ['pears', 'beets', 'olive oil']
# ['pears', 'beets', 'radishes']
# ['pears', 'beets', 'arugula']
# ['pears', 'beets', 'horseradish']
# ['pears', 'beets', 'dill']
# ['pears', 'beets', 'sugar']
# ['pears', 'beets', 'squab']
# ['pears', 'beets', 'parsley, flat-leaf']
# ['pears', 'beets', 'pepper']
# ['pears', 'beets', 'ginger']
# ['pears', 'beets', 'cream']
# ['pears', 'beets', 'sour cream']
# ['pears', 'beets', 'cheese']
# ['pears', 'beets', 'watercress']
# ['pears', 'beets', 'vinegar']
# ['pears', 'beets', 'venison']
# ['pears', 'beets', 'sweetness']
# ['pears', 'beets', 'nutmeg']
# ['pears', 'beets', 'cloves']
# ['pears', 'beets', 'maple syrup']
# ['pears', 'beets', 'salads']
# ['pears', 'beets', 'thyme']
# ['pears', 'beets', 'macadamia nuts']
# ['pears', 'beets', 'walnuts']
# ['pears', 'beets', 'basil']
# ['pears', 'beets', 'oranges—in general']
# ['pears', 'beets', 'anise hyssop']
# ['pears', 'beets', 'rutabagas']
# ['pears', 'beets', 'coriander']
# ['pears', 'beets', 'rosemary']
# ['pears', 'beets', 'allspice']
# ['pears', 'beets', 'cheese, goat—fresh']
# ['pears', 'beets', 'butter, unsalted']
# ['pears', 'beets', 'lemon']
# ['pears', 'beets', 'honey']
# ['pears', 'beets', 'hazelnuts']
# ['pears', 'beets', 'fennel']
# ['pears', 'beets', 'mint']
# ['pears', 'beets', 'apples']
# ['pears', 'pepper, pink', 'olive oil']
# ['pears', 'pepper, pink', 'chocolate']
# ['pears', 'pepper, pink', 'pepper']
# ['pears', 'pepper, pink', 'vinegar']
# ['pears', 'pepper, pink', 'game']
# ['pears', 'pepper, pink', 'pork']
# ['pears', 'pepper, pink', 'duck']
# ['pears', 'pepper, pink', 'meats']
# ['pears', 'pepper, pink', 'chicken']
# ['pears', 'pepper, pink', 'poultry']
# ['pears', 'pepper, pink', 'fennel']
# ['pears', 'pepper, pink', 'mint']
# ['pears', 'crème fraîche', 'horseradish']
# ['pears', 'crème fraîche', 'rhubarb']
# ['pears', 'crème fraîche', 'dill']
# ['pears', 'crème fraîche', 'blueberries']
# ['pears', 'crème fraîche', 'figs, fresh']
# ['pears', 'crème fraîche', 'lemons']
# ['pears', 'crème fraîche', 'melon/muskmelons—in general']
# ['pears', 'crème fraîche', 'watercress']
# ['pears', 'crème fraîche', 'raspberries']
# ['pears', 'crème fraîche', 'sweet potatoes']
# ['pears', 'crème fraîche', 'squash, butternut']
# ['pears', 'crème fraîche', 'chocolate / cocoa—in general']
# ['pears', 'crème fraîche', 'almonds']
# ['pears', 'crème fraîche', 'walnuts']
# ['pears', 'crème fraîche', 'caramel']
# ['pears', 'crème fraîche', 'plums, dried']
# ['pears', 'crème fraîche', 'mascarpone']
# ['pears', 'crème fraîche', 'chicken']
# ['pears', 'crème fraîche', 'fennel']
# ['pears', 'crème fraîche', 'dates']
# ['pears', 'crème fraîche', 'apples']
# ['pears', 'cheese—in general', 'nuts']
# ['pears', 'cheese—in general', 'cherries']
# ['pears', 'cheese—in general', 'dates']
# ['pears', 'cheese—in general', 'apples']
# ['pears', 'olive oil', 'italian cuisine']
# ['pears', 'olive oil', 'peanuts and peanut butter']
# ['pears', 'olive oil', 'radishes']
# ['pears', 'olive oil', 'ham']
# ['pears', 'olive oil', 'arugula']
# ['pears', 'olive oil', 'cheese, provolone']
# ['pears', 'olive oil', 'horseradish']
# ['pears', 'olive oil', 'squab']
# ['pears', 'olive oil', 'ginger']
# ['pears', 'olive oil', 'prosciutto']
# ['pears', 'olive oil', 'grapes']
# ['pears', 'olive oil', 'figs, fresh']
# ['pears', 'olive oil', 'lemons']
# ['pears', 'olive oil', 'squash, winter']
# ['pears', 'olive oil', 'melon/muskmelons—in general']
# ['pears', 'olive oil', 'liver, calf’s']
# ['pears', 'olive oil', 'watercress']
# ['pears', 'olive oil', 'pork—in general']
# ['pears', 'olive oil', 'vinegar']
# ['pears', 'olive oil', 'venison']
# ['pears', 'olive oil', 'sweet potatoes']
# ['pears', 'olive oil', 'foie gras']
# ['pears', 'olive oil', 'squash, butternut']
# ['pears', 'olive oil', 'salads']
# ['pears', 'olive oil', 'greens—in general']
# ['pears', 'olive oil', 'almonds']
# ['pears', 'olive oil', 'duck']
# ['pears', 'olive oil', 'meats']
# ['pears', 'olive oil', 'thyme']
# ['pears', 'olive oil', 'truffles, black']
# ['pears', 'olive oil', 'walnuts']
# ['pears', 'olive oil', 'basil']
# ['pears', 'olive oil', 'oranges—in general']
# ['pears', 'olive oil', 'bacon']
# ['pears', 'olive oil', 'pine nuts']
# ['pears', 'olive oil', 'verjus']
# ['pears', 'olive oil', 'mediterranean cuisine']
# ['pears', 'olive oil', 'radicchio']
# ['pears', 'olive oil', 'rutabagas']
# ['pears', 'olive oil', 'lettuces—in general']
# ['pears', 'olive oil', 'chicken']
# ['pears', 'olive oil', 'coriander']
# ['pears', 'olive oil', 'rosemary']
# ['pears', 'olive oil', 'cheese, pecorino']
# ['pears', 'olive oil', 'cheese, goat—fresh']
# ['pears', 'olive oil', 'cheese, parmesan']
# ['pears', 'olive oil', 'fennel']
# ['pears', 'olive oil', 'apples']
# ['pears', 'italian cuisine', 'ham']
# ['pears', 'italian cuisine', 'arugula']
# ['pears', 'italian cuisine', 'cheese, provolone']
# ['pears', 'italian cuisine', 'vinegar, vincotto']
# ['pears', 'italian cuisine', 'prosciutto']
# ['pears', 'italian cuisine', 'figs, fresh']
# ['pears', 'italian cuisine', 'melon/muskmelons—in general']
# ['pears', 'italian cuisine', 'watercress']
# ['pears', 'italian cuisine', 'pork—in general']
# ['pears', 'italian cuisine', 'nutmeg']
# ...
# ['oysters', 'parsley, flat-leaf', 'potatoes']
# ['oysters', 'parsley, flat-leaf', 'fennel']
# ['oysters', 'parsley, flat-leaf', 'cucumbers']
# ['oysters', 'paprika', 'chives']
# ['oysters', 'paprika', 'sour cream']
# ['oysters', 'paprika', 'garlic']
# ['oysters', 'paprika', 'thyme']
# ['oysters', 'paprika', 'shrimp']
# ['oysters', 'paprika', 'sorrel']
# ['oysters', 'paprika', 'leeks']
# ['oysters', 'paprika', 'mussels']
# ['oysters', 'paprika', 'tomatoes']
# ['oysters', 'paprika', 'potatoes']
# ['oysters', 'paprika', 'fennel']
# ['oysters', 'paprika', 'tarragon']
# ['oysters', 'pepper', 'sour cream']
# ['oysters', 'pepper', 'watercress']
# ['oysters', 'pepper', 'olives']
# ['oysters', 'pepper', 'caviar']
# ['oysters', 'pepper', 'garlic']
# ['oysters', 'pepper', 'clams']
# ['oysters', 'pepper', 'thyme']
# ['oysters', 'pepper', 'salmon, smoked']
# ['oysters', 'pepper', 'basil']
# ['oysters', 'pepper', 'shrimp']
# ['oysters', 'pepper', 'sorrel']
# ['oysters', 'pepper', 'leeks']
# ['oysters', 'pepper', 'mussels']
# ['oysters', 'pepper', 'tomatoes']
# ['oysters', 'pepper', 'potatoes']
# ['oysters', 'pepper', 'fennel']
# ['oysters', 'pepper', 'cucumbers']
# ['oysters', 'cocktail sauce', 'clams']
# ['oysters', 'ginger', 'cream']
# ['oysters', 'ginger', 'lemons']
# ['oysters', 'ginger', 'cilantro']
# ['oysters', 'ginger', 'watercress']
# ['oysters', 'ginger', 'vinegar']
# ['oysters', 'ginger', 'garlic']
# ['oysters', 'ginger', 'daikon']
# ['oysters', 'ginger', 'sauces']
# ['oysters', 'ginger', 'lemon verbena']
# ['oysters', 'ginger', 'bay leaf']
# ['oysters', 'ginger', 'basil']
# ['oysters', 'ginger', 'shrimp']
# ['oysters', 'ginger', 'tabasco sauce']
# ['oysters', 'ginger', 'lime, juice']
# ['oysters', 'ginger', 'leeks']
# ['oysters', 'ginger', 'soy sauce']
# ['oysters', 'ginger', 'shallots']
# ['oysters', 'ginger', 'mussels']
# ['oysters', 'ginger', 'tomatoes']
# ['oysters', 'ginger', 'potatoes']
# ['oysters', 'ginger', 'lemon']
# ['oysters', 'ginger', 'fennel']
# ['oysters', 'ginger', 'tarragon']
# ['oysters', 'ginger', 'mint']
# ['oysters', 'ginger', 'shiso leaf']
# ['oysters', 'ginger', 'apples']
# ['oysters', 'vinegar, ice wine', 'sauces']
# ['oysters', 'southern cuisine', 'shrimp']
# ['oysters', 'cream', 'lemons']
# ['oysters', 'cream', 'chives']
# ['oysters', 'cream', 'cilantro']
# ['oysters', 'cream', 'watercress']
# ['oysters', 'cream', 'daikon']
# ['oysters', 'cream', 'lemon verbena']
# ['oysters', 'cream', 'clams']
# ['oysters', 'cream', 'salmon, smoked']
# ['oysters', 'cream', 'bay leaf']
# ['oysters', 'cream', 'basil']
# ['oysters', 'cream', 'shrimp']
# ['oysters', 'cream', 'sorrel']
# ['oysters', 'cream', 'leeks']
# ['oysters', 'cream', 'shallots']
# ['oysters', 'cream', 'mussels']
# ['oysters', 'cream', 'tomatoes']
# ['oysters', 'cream', 'french cuisine, northern']
# ['oysters', 'cream', 'potatoes']
# ['oysters', 'cream', 'fennel']
# ['oysters', 'cream', 'tarragon']
# ['oysters', 'cream', 'apples']
# ['oysters', 'cream', 'cucumbers']
# ['oysters', 'lemons', 'chives']
# ['oysters', 'lemons', 'sour cream']
# ['oysters', 'lemons', 'garlic']
# ['oysters', 'lemons', 'sauces']
# ['oysters', 'lemons', 'lemon verbena']
# ['oysters', 'lemons', 'thyme']
# ['oysters', 'lemons', 'bay leaf']
# ['oysters', 'lemons', 'basil']
# ['oysters', 'lemons', 'capers']
# ['oysters', 'lemons', 'shallots']
# ['oysters', 'lemons', 'butter, unsalted']
# ['oysters', 'lemons', 'mint']
# ['oysters', 'lemons', 'apples']
# ['oysters', 'vermouth', 'clams']
# ['oysters', 'vermouth', 'shrimp']
# ['oysters', 'vermouth', 'mussels']
# ['oysters', 'vermouth', 'fennel']
# ['oysters', 'vermouth', 'apples']
# ['oysters', 'yuzu juice', 'clams']
# ['oysters', 'yuzu juice', 'shrimp']
# ['oysters', 'chives', 'cilantro']
# ['oysters', 'chives', 'sour cream']
# ['oysters', 'chives', 'watercress']
# ['oysters', 'chives', 'caviar']
# ['oysters', 'chives', 'garlic']
# ['oysters', 'chives', 'daikon']
# ['oysters', 'chives', 'sauces']
# ['oysters', 'chives', 'lemon verbena']
# ['oysters', 'chives', 'clams']
# ['oysters', 'chives', 'thyme']
# ['oysters', 'chives', 'salmon, smoked']
# ['oysters', 'chives', 'basil']
# ['oysters', 'chives', 'shrimp']
# ['oysters', 'chives', 'sorrel']
# ['oysters', 'chives', 'leeks']
# ['oysters', 'chives', 'shallots']
# ['oysters', 'chives', 'mussels']
# ['oysters', 'chives', 'tomatoes']
# ['oysters', 'chives', 'potatoes']
# ['oysters', 'chives', 'fennel']
# ['oysters', 'chives', 'tarragon']
# ['oysters', 'chives', 'shiso leaf']
# ['oysters', 'chives', 'apples']
# ['oysters', 'chives', 'cucumbers']
# ['oysters', 'cilantro', 'watercress']
# ['oysters', 'cilantro', 'garlic']
# ['oysters', 'cilantro', 'sauvignon blanc']
# ['oysters', 'cilantro', 'sauces']
# ['oysters', 'cilantro', 'lemon verbena']
# ['oysters', 'cilantro', 'clams']
# ['oysters', 'cilantro', 'salmon, smoked']
# ['oysters', 'cilantro', 'basil']
# ['oysters', 'cilantro', 'shrimp']
# ['oysters', 'cilantro', 'sorrel']
# ['oysters', 'cilantro', 'lime, juice']
# ['oysters', 'cilantro', 'soy sauce']
# ['oysters', 'cilantro', 'mussels']
# ['oysters', 'cilantro', 'tomatoes']
# ['oysters', 'cilantro', 'potatoes']
# ['oysters', 'cilantro', 'mint']
# ['oysters', 'cilantro', 'cucumbers']
# ['oysters', 'sour cream', 'caviar']
# ['oysters', 'sour cream', 'daikon']
# ['oysters', 'sour cream', 'sauces']
# ['oysters', 'sour cream', 'lemon verbena']
# ['oysters', 'sour cream', 'salmon, smoked']
# ['oysters', 'sour cream', 'shrimp']
# ['oysters', 'sour cream', 'sorrel']
# ['oysters', 'sour cream', 'potatoes']
# ['oysters', 'sour cream', 'apples']
# ['oysters', 'sour cream', 'cucumbers']
# ['oysters', 'watercress', 'vinegar']
# ['oysters', 'watercress', 'garlic']
# ['oysters', 'watercress', 'bacon']
# ['oysters', 'watercress', 'shrimp']
# ['oysters', 'watercress', 'sorrel']
# ['oysters', 'watercress', 'lime, juice']
# ['oysters', 'watercress', 'leeks']
# ['oysters', 'watercress', 'soy sauce']
# ['oysters', 'watercress', 'shallots']
# ['oysters', 'watercress', 'mussels']
# ['oysters', 'watercress', 'tomatoes']
# ['oysters', 'watercress', 'potatoes']
# ['oysters', 'watercress', 'butter, unsalted']
# ['oysters', 'watercress', 'fennel']
# ['oysters', 'watercress', 'tarragon']
# ['oysters', 'watercress', 'mint']
# ['oysters', 'watercress', 'apples']
# ['oysters', 'watercress', 'cucumbers']
# ['oysters', 'olives', 'vinegar']
# ['oysters', 'olives', 'garlic']
# ['oysters', 'olives', 'thyme']
# ['oysters', 'olives', 'bay leaf']
# ['oysters', 'olives', 'basil']
# ['oysters', 'olives', 'capers']
# ['oysters', 'olives', 'shallots']
# ['oysters', 'olives', 'tomatoes']
# ['oysters', 'olives', 'lemon']
# ['oysters', 'olives', 'fennel']
# ['oysters', 'caviar', 'clams']
# ['oysters', 'caviar', 'salmon, smoked']
# ['oysters', 'caviar', 'shrimp']
# ['oysters', 'caviar', 'sorrel']
# ['oysters', 'caviar', 'shallots']
# ['oysters', 'caviar', 'potatoes']
# ['oysters', 'caviar', 'champagne']
# ['oysters', 'caviar', 'lemon']
# ['oysters', 'vinegar', 'garlic']
# ['oysters', 'vinegar', 'daikon']
# ['oysters', 'vinegar', 'salmon, smoked']
# ['oysters', 'vinegar', 'bay leaf']
# ['oysters', 'vinegar', 'basil']
# ['oysters', 'vinegar', 'bacon']
# ['oysters', 'vinegar', 'shrimp']
# ['oysters', 'vinegar', 'capers']
# ['oysters', 'vinegar', 'shallots']
# ['oysters', 'vinegar', 'mussels']
# ['oysters', 'vinegar', 'tomatoes']
# ['oysters', 'vinegar', 'potatoes']
# ['oysters', 'vinegar', 'fennel']
# ['oysters', 'vinegar', 'tarragon']
# ['oysters', 'vinegar', 'shiso leaf']
# ['oysters', 'vinegar', 'apples']
# ['oysters', 'vinegar', 'cucumbers']
# ['oysters', 'garlic', 'cajun cuisine']
# ['oysters', 'garlic', 'sauvignon blanc']
# ['oysters', 'garlic', 'sauces']
# ['oysters', 'garlic', 'lemon verbena']
# ['oysters', 'garlic', 'clams']
# ['oysters', 'garlic', 'autumn']
# ['oysters', 'garlic', 'thyme']
# ['oysters', 'garlic', 'salmon, smoked']
# ['oysters', 'garlic', 'bay leaf']
# ['oysters', 'garlic', 'basil']
# ['oysters', 'garlic', 'bacon']
# ['oysters', 'garlic', 'shrimp']
# ['oysters', 'garlic', 'sorrel']
# ['oysters', 'garlic', 'capers']
# ['oysters', 'garlic', 'lime, juice']
# ['oysters', 'garlic', 'leeks']
# ['oysters', 'garlic', 'soy sauce']
# ['oysters', 'garlic', 'shallots']
# ['oysters', 'garlic', 'mussels']
# ['oysters', 'garlic', 'tomatoes']
# ['oysters', 'garlic', 'potatoes']
# ['oysters', 'garlic', 'lemon']
# ['oysters', 'garlic', 'fennel']
# ['oysters', 'garlic', 'tarragon']
# ['oysters', 'garlic', 'cucumbers']
# ['oysters', 'cajun cuisine', 'shrimp']
# ['oysters', 'cajun cuisine', 'tomatoes']
# ['oysters', 'chili sauce', 'shrimp']
# ['oysters', 'chili sauce', 'tomatoes']
# ['oysters', 'sauvignon blanc', 'tomatoes']
# ['oysters', 'daikon', 'thyme']
# ['oysters', 'daikon', 'salmon, smoked']
# ['oysters', 'daikon', 'basil']
# ['oysters', 'daikon', 'soy sauce']
# ['oysters', 'daikon', 'mint']
# ['oysters', 'daikon', 'cucumbers']
# ['oysters', 'sauces', 'thyme']
# ['oysters', 'sauces', 'bay leaf']
# ['oysters', 'sauces', 'basil']
# ['oysters', 'sauces', 'capers']
# ['oysters', 'sauces', 'shallots']
# ['oysters', 'sauces', 'tomatoes']
# ['oysters', 'sauces', 'fennel']
# ['oysters', 'sea urchin', 'shiso leaf']
# ['oysters', 'lemon verbena', 'thyme']
# ['oysters', 'lemon verbena', 'basil']
# ['oysters', 'lemon verbena', 'sorrel']
# ['oysters', 'lemon verbena', 'lime, juice']
# ['oysters', 'lemon verbena', 'butter, unsalted']
# ['oysters', 'lemon verbena', 'mint']
# ['oysters', 'clams', 'thyme']
# ['oysters', 'clams', 'bay leaf']
# ['oysters', 'clams', 'basil']
# ['oysters', 'clams', 'bacon']
# ['oysters', 'clams', 'shrimp']
# ['oysters', 'clams', 'sake']
# ['oysters', 'clams', 'capers']
# ['oysters', 'clams', 'tabasco sauce']
# ['oysters', 'clams', 'lime, juice']
# ['oysters', 'clams', 'leeks']
# ['oysters', 'clams', 'soy sauce']
# ['oysters', 'clams', 'shallots']
# ['oysters', 'clams', 'mussels']
# ['oysters', 'clams', 'tomatoes']
# ['oysters', 'clams', 'potatoes']
# ['oysters', 'clams', 'aioli']
# ['oysters', 'clams', 'butter, unsalted']
# ['oysters', 'clams', 'fennel']
# ['oysters', 'clams', 'tarragon']
# ['oysters', 'clams', 'mint']
# ['oysters', 'clams', 'shiso leaf']
# ['oysters', 'autumn', 'basil']
# ['oysters', 'autumn', 'tomatoes']
# ['oysters', 'autumn', 'fennel']
# ['oysters', 'autumn', 'apples']
# ['oysters', 'autumn', 'cucumbers']
# ['oysters', 'thyme', 'bay leaf']
# ['oysters', 'thyme', 'basil']
# ['oysters', 'thyme', 'bacon']
# ['oysters', 'thyme', 'leeks']
# ['oysters', 'thyme', 'shallots']
# ['oysters', 'thyme', 'mussels']
# ['oysters', 'thyme', 'tomatoes']
# ['oysters', 'thyme', 'potatoes']
# ['oysters', 'thyme', 'lemon']
# ['oysters', 'thyme', 'fennel']
# ['oysters', 'thyme', 'tarragon']
# ['oysters', 'thyme', 'mint']
# ['oysters', 'thyme', 'apples']
# ['oysters', 'thyme', 'cucumbers']
# ['oysters', 'salmon, smoked', 'sorrel']
# ['oysters', 'salmon, smoked', 'capers']
# ['oysters', 'salmon, smoked', 'tabasco sauce']
# ['oysters', 'salmon, smoked', 'leeks']
# ['oysters', 'salmon, smoked', 'soy sauce']
# ['oysters', 'salmon, smoked', 'shallots']
# ['oysters', 'salmon, smoked', 'tomatoes']
# ['oysters', 'salmon, smoked', 'potatoes']
# ['oysters', 'salmon, smoked', 'champagne']
# ['oysters', 'salmon, smoked', 'lemon']
# ['oysters', 'salmon, smoked', 'tarragon']
# ['oysters', 'salmon, smoked', 'shiso leaf']
# ['oysters', 'salmon, smoked', 'cucumbers']
# ['oysters', 'bay leaf', 'shrimp']
# ['oysters', 'bay leaf', 'leeks']
# ['oysters', 'bay leaf', 'mussels']
# ['oysters', 'bay leaf', 'tomatoes']
# ['oysters', 'bay leaf', 'potatoes']
# ['oysters', 'bay leaf', 'fennel']
# ['oysters', 'bay leaf', 'tarragon']
# ['oysters', 'bay leaf', 'apples']
# ['oysters', 'basil', 'shrimp']
# ['oysters', 'basil', 'sorrel']
# ['oysters', 'basil', 'capers']
# ['oysters', 'basil', 'lime, juice']
# ['oysters', 'basil', 'soy sauce']
# ['oysters', 'basil', 'mussels']
# ['oysters', 'basil', 'potatoes']
# ['oysters', 'basil', 'fennel']
# ['oysters', 'basil', 'tarragon']
# ['oysters', 'basil', 'mint']
# ['oysters', 'basil', 'shiso leaf']
# ['oysters', 'basil', 'cucumbers']
# ['oysters', 'bacon', 'shrimp']
# ['oysters', 'bacon', 'sorrel']
# ['oysters', 'bacon', 'leeks']
# ['oysters', 'bacon', 'shallots']
# ['oysters', 'bacon', 'mussels']
# ['oysters', 'bacon', 'tomatoes']
# ['oysters', 'bacon', 'potatoes']
# ['oysters', 'bacon', 'aioli']
# ['oysters', 'bacon', 'risotto']
# ['oysters', 'bacon', 'butter, unsalted']
# ['oysters', 'bacon', 'apples']
# ['oysters', 'shrimp', 'sake']
# ['oysters', 'shrimp', 'capers']
# ['oysters', 'shrimp', 'tabasco sauce']
# ['oysters', 'shrimp', 'bread crumbs, panko']
# ['oysters', 'shrimp', 'leeks']
# ['oysters', 'shrimp', 'soy sauce']
# ['oysters', 'shrimp', 'shallots']
# ['oysters', 'shrimp', 'mussels']
# ['oysters', 'shrimp', 'tomatoes']
# ['oysters', 'shrimp', 'risotto']
# ['oysters', 'shrimp', 'butter, unsalted']
# ['oysters', 'shrimp', 'lemon']
# ['oysters', 'shrimp', 'fennel']
# ['oysters', 'shrimp', 'tarragon']
# ['oysters', 'shrimp', 'mint']
# ['oysters', 'shrimp', 'shiso leaf']
# ['oysters', 'shrimp', 'apples']
# ['oysters', 'shrimp', 'cucumbers']
# ['oysters', 'sorrel', 'leeks']
# ['oysters', 'sorrel', 'shallots']
# ['oysters', 'sorrel', 'mussels']
# ['oysters', 'sorrel', 'tomatoes']
# ['oysters', 'sorrel', 'potatoes']
# ['oysters', 'sorrel', 'butter, unsalted']
# ['oysters', 'sorrel', 'tarragon']
# ['oysters', 'sorrel', 'mint']
# ['oysters', 'sorrel', 'apples']
# ['oysters', 'sorrel', 'cucumbers']
# ['oysters', 'capers', 'leeks']
# ['oysters', 'capers', 'shallots']
# ['oysters', 'capers', 'mussels']
# ['oysters', 'capers', 'tomatoes']
# ['oysters', 'capers', 'potatoes']
# ['oysters', 'capers', 'tarragon']
# ['oysters', 'tabasco sauce', 'tomatoes']
# ['oysters', 'tabasco sauce', 'cucumbers']
# ['oysters', 'lime, juice', 'tomatoes']
# ['oysters', 'lime, juice', 'cucumbers']
# ['oysters', 'leeks', 'soy sauce']
# ['oysters', 'leeks', 'mussels']
# ['oysters', 'leeks', 'tomatoes']
# ['oysters', 'leeks', 'potatoes']
# ['oysters', 'leeks', 'butter, unsalted']
# ['oysters', 'leeks', 'fennel']
# ['oysters', 'leeks', 'tarragon']
# ['oysters', 'soy sauce', 'tarragon']
# ['oysters', 'soy sauce', 'shiso leaf']
# ['oysters', 'soy sauce', 'cucumbers']
# ['oysters', 'shallots', 'mussels']
# ['oysters', 'shallots', 'tomatoes']
# ['oysters', 'shallots', 'potatoes']
# ['oysters', 'shallots', 'fennel']
# ['oysters', 'shallots', 'tarragon']
# ['oysters', 'shallots', 'cucumbers']
# ['oysters', 'mussels', 'tomatoes']
# ['oysters', 'mussels', 'potatoes']
# ['oysters', 'mussels', 'butter, unsalted']
# ['oysters', 'mussels', 'fennel']
# ['oysters', 'mussels', 'tarragon']
# ['oysters', 'mussels', 'mint']
# ['oysters', 'tomatoes', 'potatoes']
# ['oysters', 'tomatoes', 'aioli']
# ['oysters', 'tomatoes', 'butter, unsalted']
# ['oysters', 'tomatoes', 'lemon']
# ['oysters', 'tomatoes', 'fennel']
# ['oysters', 'tomatoes', 'tarragon']
# ['oysters', 'tomatoes', 'mint']
# ['oysters', 'tomatoes', 'cucumbers']
# ['oysters', 'french cuisine, northern', 'apples']
# ['oysters', 'potatoes', 'butter, unsalted']
# ['oysters', 'potatoes', 'fennel']
# ['oysters', 'potatoes', 'tarragon']
# ['oysters', 'champagne', 'lemon']
# ['oysters', 'champagne', 'mint']
# ['oysters', 'butter, unsalted', 'fennel']
# ['oysters', 'butter, unsalted', 'apples']
# ['oysters', 'lemon', 'fennel']
# ['oysters', 'lemon', 'shiso leaf']
# ['oysters', 'lemon', 'apples']
# ['oysters', 'fennel', 'tarragon']
# ['oysters', 'fennel', 'mint']
# ['oysters', 'fennel', 'apples']
# ['oysters', 'fennel', 'cucumbers']
# ['oysters', 'tarragon', 'mint']
# ['oysters', 'tarragon', 'apples']
# ['oysters', 'tarragon', 'cucumbers']
# ['oysters', 'mint', 'shiso leaf']
# ['oysters', 'mint', 'cucumbers']
# ['oysters', 'shiso leaf', 'apples']
# ['oysters', 'shiso leaf', 'cucumbers']
# ['oil, hazelnut', 'squab', 'figs']
# ['oil, hazelnut', 'pastries', 'hazelnuts']
# ['oil, hazelnut', 'sauces', 'hazelnuts']
# ['oil, hazelnut', 'salads', 'apples']
# ['oil, hazelnut', 'broccoli', 'lemon, juice']
# ['oil, hazelnut', 'figs', 'hazelnuts']
# ['oil, hazelnut', 'hazelnuts', 'apples']
# ['fennel bulb', 'anise hyssop', 'tarragon']
# ['beets', 'crème fraîche', 'asparagus']
# ['beets', 'crème fraîche', 'horseradish']
# ['beets', 'crème fraîche', 'dill']
# ['beets', 'crème fraîche', 'mackerel']
# ['beets', 'crème fraîche', 'beans, green']
# ['beets', 'crème fraîche', 'chives']
# ['beets', 'crème fraîche', 'watercress']
# ['beets', 'crème fraîche', 'caviar']
# ['beets', 'crème fraîche', 'lemon verbena']
# ['beets', 'crème fraîche', 'chicory']
# ['beets', 'crème fraîche', 'bass, sea']
# ['beets', 'crème fraîche', 'walnuts']
# ['beets', 'crème fraîche', 'lobster']
# ['beets', 'crème fraîche', 'onions—in general']
# ['beets', 'crème fraîche', 'celery root']
# ['beets', 'crème fraîche', 'leeks']
# ['beets', 'crème fraîche', 'carrots']
